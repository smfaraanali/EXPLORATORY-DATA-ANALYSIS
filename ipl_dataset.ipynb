# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
ipl_match = pd.read_csv('F:\IPL Matches 2008-2020.csv')

# %%
ipl_match.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl_match['id'].value_counts()
# Out:
# 335982     1
# 980963     1
# 980943     1
# 980945     1
# 980947     1
#           ..
# 548332     1
# 548333     1
# 548334     1
# 548335     1
# 1237181    1
# Name: id, Length: 816, dtype: int64

# %%
ipl_match['city'].value_counts()[0:5]
# Out:
# Mumbai       101
# Kolkata       77
# Delhi         74
# Bangalore     65
# Hyderabad     64
# Name: city, dtype: int64

# %%
plt.figure(figsize=[8,8])
plt.pie(ipl_match['city'].value_counts(), labels = ipl_match['city'].value_counts().keys(), autopct = '%0.1f%%')
plt.show()

# %%
win_by_runs = ipl_match[ipl_match['result']=='runs']

# %%
win_by_runs['winner'].value_counts()
# Out:
# Mumbai Indians                 62
# Chennai Super Kings            53
# Kolkata Knight Riders          41
# Kings XI Punjab                40
# Royal Challengers Bangalore    38
# Sunrisers Hyderabad            34
# Rajasthan Royals               28
# Delhi Daredevils               25
# Deccan Chargers                18
# Delhi Capitals                  9
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
k = list[ipl_match['winner'].value_counts().keys]

# %%
list[win_by_runs['winner'].value_counts()]
# Out:
# list[Mumbai Indians                 62
# Chennai Super Kings            53
# Kolkata Knight Riders          41
# Kings XI Punjab                40
# Royal Challengers Bangalore    38
# Sunrisers Hyderabad            34
# Rajasthan Royals               28
# Delhi Daredevils               25
# Deccan Chargers                18
# Delhi Capitals                  9
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64]

# %%
plt.figure(figsize=[8,8])
plt.pie(win_by_runs['winner'].value_counts(), labels = win_by_runs['winner'].value_counts().keys(), autopct = '%0.1f%%')
plt.show()

# %%
win_by_wickets= ipl_match[ipl_match['result']=='wickets']

# %%
win_by_wickets.head()
# Out:
#        id       city        date player_of_match  \
# 2  335984      Delhi  2008-04-19     MF Maharoof
# 3  335985     Mumbai  2008-04-20      MV Boucher
# 4  335986    Kolkata  2008-04-20       DJ Hussey
# 5  335987     Jaipur  2008-04-21       SR Watson
# 6  335988  Hyderabad  2008-04-22        V Sehwag
#
#                                        venue  neutral_venue  \
# 2                           Feroz Shah Kotla              0
# 3                           Wankhede Stadium              0
# 4                               Eden Gardens              0
# 5                     Sawai Mansingh Stadium              0
# 6  Rajiv Gandhi International Stadium, Uppal              0
#
#                    team1                        team2       toss_winner  \
# 2       Delhi Daredevils             Rajasthan Royals  Rajasthan Royals
# 3         Mumbai Indians  Royal Challengers Bangalore    Mumbai Indians
# 4  Kolkata Knight Riders              Deccan Chargers   Deccan Chargers
# ...

# %%
win_by_wickets['winner'].value_counts()
# Out:
# Kolkata Knight Riders          57
# Mumbai Indians                 56
# Chennai Super Kings            53
# Royal Challengers Bangalore    51
# Rajasthan Royals               51
# Kings XI Punjab                45
# Delhi Daredevils               42
# Sunrisers Hyderabad            31
# Gujarat Lions                  12
# Deccan Chargers                11
# Delhi Capitals                  8
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=[8,8])
plt.pie(win_by_wickets['winner'].value_counts(), labels = win_by_wickets['winner'].value_counts().keys(), autopct= '%0.1f%%')
plt.show()

# %%
ipl_match['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
ipl_match['player_of_match'].value_counts()[0:5]
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=[6,7])
plt.pie(ipl_match['player_of_match'].value_counts()[0:5], labels = ipl_match['player_of_match'].value_counts().keys()[0:5], autopct= '%0.1f%%', )
plt.show()

# %%
ipl_match.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl_match[ipl_match['result'] == 'runs'].head()
# Out:
#         id        city        date player_of_match  \
# 0   335982   Bangalore  2008-04-18     BB McCullum
# 1   335983  Chandigarh  2008-04-19      MEK Hussey
# 7   335989     Chennai  2008-04-23       ML Hayden
# 9   335991  Chandigarh  2008-04-25   KC Sangakkara
# 14  335996   Bangalore  2008-04-28        MS Dhoni
#
#                                          venue  neutral_venue  \
# 0                        M Chinnaswamy Stadium              0
# 1   Punjab Cricket Association Stadium, Mohali              0
# 7              MA Chidambaram Stadium, Chepauk              0
# 9   Punjab Cricket Association Stadium, Mohali              0
# 14                       M Chinnaswamy Stadium              0
#
#                           team1                  team2  \
# 0   Royal Challengers Bangalore  Kolkata Knight Riders
# 1               Kings XI Punjab    Chennai Super Kings
# 7           Chennai Super Kings         Mumbai Indians
# 9               Kings XI Punjab         Mumbai Indians
# ...

# %%
win_by_runs['result_margin'].value_counts()
# Out:
# 10.0     13
# 14.0     13
# 4.0      11
# 37.0     10
# 15.0     10
#          ..
# 42.0      1
# 47.0      1
# 87.0      1
# 130.0     1
# 69.0      1
# Name: result_margin, Length: 91, dtype: int64

# %%
plt.hist(win_by_runs['result_margin'])
plt.show()

# %%
win_by_wickets['result_margin'].value_counts()
# Out:
# 6.0     88
# 7.0     84
# 5.0     79
# 8.0     62
# 4.0     42
# 9.0     39
# 3.0     18
# 10.0    14
# 2.0      6
# 1.0      3
# Name: result_margin, dtype: int64

# %%
plt.hist(win_by_wickets['result_margin'])
plt.show()
